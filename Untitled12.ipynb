# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshaikify/Artificial-Intelligence/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = np.random.rand(100)
labels = ["Class1" if x <= 0.5 else "Class2" for x in data[:50]]
def knn_classifier(train_data, train_labels, test_point, k):
 distances = sorted([(abs(test_point - train_data[i]), train_labels[i]) for i in range(len(train_data))],
key=lambda x: x[0])
 k_nearest_labels = [label for _, label in distances[:k]]
 return Counter(k_nearest_labels).most_common(1)[0][0]

# %%
train_data, train_labels = data[:50], labels
test_data = data[50:]
k_values = [1, 2, 3, 4, 5, 20, 30]
print("--- k-Nearest Neighbors Classification ---")
print("Training dataset: First 50 points labeled based on (x <= 0.5 -> Class1, x > 0.5 -> Class2)")
print("Testing dataset: Remaining 50 points to be classified\n")
results = {k: [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data] for k in
k_values}
# Out:
# --- k-Nearest Neighbors Classification ---
# Training dataset: First 50 points labeled based on (x <= 0.5 -> Class1, x > 0.5 -> Class2)
# Testing dataset: Remaining 50 points to be classified

# %%
for k, classified_labels in results.items():
    print(f"Results for k = {k}:")
    for i, label in enumerate(classified_labels, start=51):
        print(f"Point x{i} (value: {test_data[i - 51]:.4f}) is classified as {label})")
    print()
print("Classification complete.\n")
# Out:
# Results for k = 1:
# Point x51 (value: 0.3944) is classified as Class1)
# Point x52 (value: 0.4510) is classified as Class1)
# Point x53 (value: 0.9226) is classified as Class2)
# Point x54 (value: 0.8060) is classified as Class2)
# Point x55 (value: 0.4008) is classified as Class1)
# Point x56 (value: 0.4099) is classified as Class1)
# Point x57 (value: 0.0149) is classified as Class1)
# Point x58 (value: 0.3972) is classified as Class1)
# Point x59 (value: 0.5175) is classified as Class2)
# Point x60 (value: 0.0292) is classified as Class1)
# Point x61 (value: 0.0844) is classified as Class1)
# Point x62 (value: 0.1957) is classified as Class1)
# Point x63 (value: 0.0299) is classified as Class1)
# Point x64 (value: 0.9175) is classified as Class2)
# Point x65 (value: 0.2251) is classified as Class1)
# Point x66 (value: 0.9181) is classified as Class2)
# Point x67 (value: 0.3570) is classified as Class1)
# Point x68 (value: 0.2049) is classified as Class1)
# Point x69 (value: 0.9364) is classified as Class2)
# Point x70 (value: 0.9456) is classified as Class2)
# Point x71 (value: 0.2084) is classified as Class1)
# Point x72 (value: 0.5485) is classified as Class2)
# Point x73 (value: 0.9976) is classified as Class2)
# Point x74 (value: 0.7723) is classified as Class2)
# Point x75 (value: 0.9661) is classified as Class2)
# Point x76 (value: 0.4098) is classified as Class1)
# Point x77 (value: 0.4916) is classified as Class1)
# Point x78 (value: 0.0469) is classified as Class1)
# Point x79 (value: 0.8428) is classified as Class2)
# Point x80 (value: 0.5137) is classified as Class1)
# Point x81 (value: 0.8904) is classified as Class2)
# Point x82 (value: 0.0329) is classified as Class1)
# Point x83 (value: 0.0187) is classified as Class1)
# Point x84 (value: 0.8048) is classified as Class2)
# Point x85 (value: 0.7959) is classified as Class2)
# Point x86 (value: 0.8088) is classified as Class2)
# Point x87 (value: 0.1517) is classified as Class1)
# Point x88 (value: 0.5373) is classified as Class2)
# Point x89 (value: 0.5950) is classified as Class2)
# Point x90 (value: 0.9586) is classified as Class2)
# Point x91 (value: 0.5196) is classified as Class2)
# Point x92 (value: 0.7182) is classified as Class2)
# Point x93 (value: 0.6060) is classified as Class2)
# Point x94 (value: 0.3355) is classified as Class1)
# Point x95 (value: 0.0288) is classified as Class1)
# Point x96 (value: 0.0194) is classified as Class1)
# Point x97 (value: 0.0044) is classified as Class1)
# Point x98 (value: 0.3732) is classified as Class1)
# Point x99 (value: 0.7116) is classified as Class2)
# Point x100 (value: 0.3834) is classified as Class1)
#
# Results for k = 2:
# Point x51 (value: 0.3944) is classified as Class1)
# Point x52 (value: 0.4510) is classified as Class1)
# Point x53 (value: 0.9226) is classified as Class2)
# Point x54 (value: 0.8060) is classified as Class2)
# Point x55 (value: 0.4008) is classified as Class1)
# Point x56 (value: 0.4099) is classified as Class1)
# Point x57 (value: 0.0149) is classified as Class1)
# Point x58 (value: 0.3972) is classified as Class1)
# Point x59 (value: 0.5175) is classified as Class2)
# Point x60 (value: 0.0292) is classified as Class1)
# Point x61 (value: 0.0844) is classified as Class1)
# Point x62 (value: 0.1957) is classified as Class1)
# Point x63 (value: 0.0299) is classified as Class1)
# Point x64 (value: 0.9175) is classified as Class2)
# Point x65 (value: 0.2251) is classified as Class1)
# Point x66 (value: 0.9181) is classified as Class2)
# Point x67 (value: 0.3570) is classified as Class1)
# Point x68 (value: 0.2049) is classified as Class1)
# Point x69 (value: 0.9364) is classified as Class2)
# Point x70 (value: 0.9456) is classified as Class2)
# Point x71 (value: 0.2084) is classified as Class1)
# Point x72 (value: 0.5485) is classified as Class2)
# Point x73 (value: 0.9976) is classified as Class2)
# Point x74 (value: 0.7723) is classified as Class2)
# Point x75 (value: 0.9661) is classified as Class2)
# Point x76 (value: 0.4098) is classified as Class1)
# Point x77 (value: 0.4916) is classified as Class1)
# Point x78 (value: 0.0469) is classified as Class1)
# Point x79 (value: 0.8428) is classified as Class2)
# Point x80 (value: 0.5137) is classified as Class1)
# Point x81 (value: 0.8904) is classified as Class2)
# Point x82 (value: 0.0329) is classified as Class1)
# Point x83 (value: 0.0187) is classified as Class1)
# Point x84 (value: 0.8048) is classified as Class2)
# Point x85 (value: 0.7959) is classified as Class2)
# Point x86 (value: 0.8088) is classified as Class2)
# Point x87 (value: 0.1517) is classified as Class1)
# Point x88 (value: 0.5373) is classified as Class2)
# Point x89 (value: 0.5950) is classified as Class2)
# Point x90 (value: 0.9586) is classified as Class2)
# Point x91 (value: 0.5196) is classified as Class2)
# Point x92 (value: 0.7182) is classified as Class2)
# Point x93 (value: 0.6060) is classified as Class2)
# Point x94 (value: 0.3355) is classified as Class1)
# Point x95 (value: 0.0288) is classified as Class1)
# Point x96 (value: 0.0194) is classified as Class1)
# Point x97 (value: 0.0044) is classified as Class1)
# Point x98 (value: 0.3732) is classified as Class1)
# Point x99 (value: 0.7116) is classified as Class2)
# Point x100 (value: 0.3834) is classified as Class1)
#
# Results for k = 3:
# Point x51 (value: 0.3944) is classified as Class1)
# Point x52 (value: 0.4510) is classified as Class1)
# Point x53 (value: 0.9226) is classified as Class2)
# Point x54 (value: 0.8060) is classified as Class2)
# Point x55 (value: 0.4008) is classified as Class1)
# Point x56 (value: 0.4099) is classified as Class1)
# Point x57 (value: 0.0149) is classified as Class1)
# Point x58 (value: 0.3972) is classified as Class1)
# Point x59 (value: 0.5175) is classified as Class2)
# Point x60 (value: 0.0292) is classified as Class1)
# Point x61 (value: 0.0844) is classified as Class1)
# Point x62 (value: 0.1957) is classified as Class1)
# Point x63 (value: 0.0299) is classified as Class1)
# Point x64 (value: 0.9175) is classified as Class2)
# Point x65 (value: 0.2251) is classified as Class1)
# Point x66 (value: 0.9181) is classified as Class2)
# Point x67 (value: 0.3570) is classified as Class1)
# Point x68 (value: 0.2049) is classified as Class1)
# Point x69 (value: 0.9364) is classified as Class2)
# Point x70 (value: 0.9456) is classified as Class2)
# Point x71 (value: 0.2084) is classified as Class1)
# Point x72 (value: 0.5485) is classified as Class2)
# Point x73 (value: 0.9976) is classified as Class2)
# Point x74 (value: 0.7723) is classified as Class2)
# Point x75 (value: 0.9661) is classified as Class2)
# Point x76 (value: 0.4098) is classified as Class1)
# Point x77 (value: 0.4916) is classified as Class1)
# Point x78 (value: 0.0469) is classified as Class1)
# Point x79 (value: 0.8428) is classified as Class2)
# Point x80 (value: 0.5137) is classified as Class2)
# Point x81 (value: 0.8904) is classified as Class2)
# Point x82 (value: 0.0329) is classified as Class1)
# Point x83 (value: 0.0187) is classified as Class1)
# Point x84 (value: 0.8048) is classified as Class2)
# Point x85 (value: 0.7959) is classified as Class2)
# Point x86 (value: 0.8088) is classified as Class2)
# Point x87 (value: 0.1517) is classified as Class1)
# Point x88 (value: 0.5373) is classified as Class2)
# Point x89 (value: 0.5950) is classified as Class2)
# Point x90 (value: 0.9586) is classified as Class2)
# Point x91 (value: 0.5196) is classified as Class2)
# Point x92 (value: 0.7182) is classified as Class2)
# Point x93 (value: 0.6060) is classified as Class2)
# Point x94 (value: 0.3355) is classified as Class1)
# Point x95 (value: 0.0288) is classified as Class1)
# Point x96 (value: 0.0194) is classified as Class1)
# Point x97 (value: 0.0044) is classified as Class1)
# Point x98 (value: 0.3732) is classified as Class1)
# Point x99 (value: 0.7116) is classified as Class2)
# Point x100 (value: 0.3834) is classified as Class1)
#
# Results for k = 4:
# Point x51 (value: 0.3944) is classified as Class1)
# Point x52 (value: 0.4510) is classified as Class1)
# Point x53 (value: 0.9226) is classified as Class2)
# Point x54 (value: 0.8060) is classified as Class2)
# Point x55 (value: 0.4008) is classified as Class1)
# Point x56 (value: 0.4099) is classified as Class1)
# Point x57 (value: 0.0149) is classified as Class1)
# Point x58 (value: 0.3972) is classified as Class1)
# Point x59 (value: 0.5175) is classified as Class2)
# Point x60 (value: 0.0292) is classified as Class1)
# Point x61 (value: 0.0844) is classified as Class1)
# Point x62 (value: 0.1957) is classified as Class1)
# Point x63 (value: 0.0299) is classified as Class1)
# Point x64 (value: 0.9175) is classified as Class2)
# Point x65 (value: 0.2251) is classified as Class1)
# Point x66 (value: 0.9181) is classified as Class2)
# Point x67 (value: 0.3570) is classified as Class1)
# Point x68 (value: 0.2049) is classified as Class1)
# Point x69 (value: 0.9364) is classified as Class2)
# Point x70 (value: 0.9456) is classified as Class2)
# Point x71 (value: 0.2084) is classified as Class1)
# Point x72 (value: 0.5485) is classified as Class2)
# Point x73 (value: 0.9976) is classified as Class2)
# Point x74 (value: 0.7723) is classified as Class2)
# Point x75 (value: 0.9661) is classified as Class2)
# Point x76 (value: 0.4098) is classified as Class1)
# Point x77 (value: 0.4916) is classified as Class1)
# Point x78 (value: 0.0469) is classified as Class1)
# Point x79 (value: 0.8428) is classified as Class2)
# Point x80 (value: 0.5137) is classified as Class2)
# Point x81 (value: 0.8904) is classified as Class2)
# Point x82 (value: 0.0329) is classified as Class1)
# Point x83 (value: 0.0187) is classified as Class1)
# Point x84 (value: 0.8048) is classified as Class2)
# Point x85 (value: 0.7959) is classified as Class2)
# Point x86 (value: 0.8088) is classified as Class2)
# Point x87 (value: 0.1517) is classified as Class1)
# Point x88 (value: 0.5373) is classified as Class2)
# Point x89 (value: 0.5950) is classified as Class2)
# Point x90 (value: 0.9586) is classified as Class2)
# Point x91 (value: 0.5196) is classified as Class2)
# Point x92 (value: 0.7182) is classified as Class2)
# Point x93 (value: 0.6060) is classified as Class2)
# Point x94 (value: 0.3355) is classified as Class1)
# Point x95 (value: 0.0288) is classified as Class1)
# Point x96 (value: 0.0194) is classified as Class1)
# Point x97 (value: 0.0044) is classified as Class1)
# Point x98 (value: 0.3732) is classified as Class1)
# Point x99 (value: 0.7116) is classified as Class2)
# Point x100 (value: 0.3834) is classified as Class1)
#
# Results for k = 5:
# Point x51 (value: 0.3944) is classified as Class1)
# Point x52 (value: 0.4510) is classified as Class1)
# Point x53 (value: 0.9226) is classified as Class2)
# Point x54 (value: 0.8060) is classified as Class2)
# Point x55 (value: 0.4008) is classified as Class1)
# Point x56 (value: 0.4099) is classified as Class1)
# Point x57 (value: 0.0149) is classified as Class1)
# Point x58 (value: 0.3972) is classified as Class1)
# Point x59 (value: 0.5175) is classified as Class2)
# Point x60 (value: 0.0292) is classified as Class1)
# Point x61 (value: 0.0844) is classified as Class1)
# Point x62 (value: 0.1957) is classified as Class1)
# Point x63 (value: 0.0299) is classified as Class1)
# Point x64 (value: 0.9175) is classified as Class2)
# Point x65 (value: 0.2251) is classified as Class1)
# Point x66 (value: 0.9181) is classified as Class2)
# Point x67 (value: 0.3570) is classified as Class1)
# Point x68 (value: 0.2049) is classified as Class1)
# Point x69 (value: 0.9364) is classified as Class2)
# Point x70 (value: 0.9456) is classified as Class2)
# Point x71 (value: 0.2084) is classified as Class1)
# Point x72 (value: 0.5485) is classified as Class2)
# Point x73 (value: 0.9976) is classified as Class2)
# Point x74 (value: 0.7723) is classified as Class2)
# Point x75 (value: 0.9661) is classified as Class2)
# Point x76 (value: 0.4098) is classified as Class1)
# Point x77 (value: 0.4916) is classified as Class1)
# Point x78 (value: 0.0469) is classified as Class1)
# Point x79 (value: 0.8428) is classified as Class2)
# Point x80 (value: 0.5137) is classified as Class2)
# Point x81 (value: 0.8904) is classified as Class2)
# Point x82 (value: 0.0329) is classified as Class1)
# Point x83 (value: 0.0187) is classified as Class1)
# Point x84 (value: 0.8048) is classified as Class2)
# Point x85 (value: 0.7959) is classified as Class2)
# Point x86 (value: 0.8088) is classified as Class2)
# Point x87 (value: 0.1517) is classified as Class1)
# Point x88 (value: 0.5373) is classified as Class2)
# Point x89 (value: 0.5950) is classified as Class2)
# Point x90 (value: 0.9586) is classified as Class2)
# Point x91 (value: 0.5196) is classified as Class2)
# Point x92 (value: 0.7182) is classified as Class2)
# Point x93 (value: 0.6060) is classified as Class2)
# Point x94 (value: 0.3355) is classified as Class1)
# Point x95 (value: 0.0288) is classified as Class1)
# Point x96 (value: 0.0194) is classified as Class1)
# Point x97 (value: 0.0044) is classified as Class1)
# Point x98 (value: 0.3732) is classified as Class1)
# Point x99 (value: 0.7116) is classified as Class2)
# Point x100 (value: 0.3834) is classified as Class1)
#
# Results for k = 20:
# Point x51 (value: 0.3944) is classified as Class1)
# Point x52 (value: 0.4510) is classified as Class1)
# Point x53 (value: 0.9226) is classified as Class2)
# Point x54 (value: 0.8060) is classified as Class2)
# Point x55 (value: 0.4008) is classified as Class1)
# Point x56 (value: 0.4099) is classified as Class1)
# Point x57 (value: 0.0149) is classified as Class1)
# Point x58 (value: 0.3972) is classified as Class1)
# Point x59 (value: 0.5175) is classified as Class1)
# Point x60 (value: 0.0292) is classified as Class1)
# Point x61 (value: 0.0844) is classified as Class1)
# Point x62 (value: 0.1957) is classified as Class1)
# Point x63 (value: 0.0299) is classified as Class1)
# Point x64 (value: 0.9175) is classified as Class2)
# Point x65 (value: 0.2251) is classified as Class1)
# Point x66 (value: 0.9181) is classified as Class2)
# Point x67 (value: 0.3570) is classified as Class1)
# Point x68 (value: 0.2049) is classified as Class1)
# Point x69 (value: 0.9364) is classified as Class2)
# Point x70 (value: 0.9456) is classified as Class2)
# Point x71 (value: 0.2084) is classified as Class1)
# Point x72 (value: 0.5485) is classified as Class2)
# Point x73 (value: 0.9976) is classified as Class2)
# Point x74 (value: 0.7723) is classified as Class2)
# Point x75 (value: 0.9661) is classified as Class2)
# Point x76 (value: 0.4098) is classified as Class1)
# Point x77 (value: 0.4916) is classified as Class1)
# Point x78 (value: 0.0469) is classified as Class1)
# Point x79 (value: 0.8428) is classified as Class2)
# Point x80 (value: 0.5137) is classified as Class1)
# Point x81 (value: 0.8904) is classified as Class2)
# Point x82 (value: 0.0329) is classified as Class1)
# Point x83 (value: 0.0187) is classified as Class1)
# Point x84 (value: 0.8048) is classified as Class2)
# Point x85 (value: 0.7959) is classified as Class2)
# Point x86 (value: 0.8088) is classified as Class2)
# Point x87 (value: 0.1517) is classified as Class1)
# Point x88 (value: 0.5373) is classified as Class2)
# Point x89 (value: 0.5950) is classified as Class2)
# Point x90 (value: 0.9586) is classified as Class2)
# Point x91 (value: 0.5196) is classified as Class2)
# Point x92 (value: 0.7182) is classified as Class2)
# Point x93 (value: 0.6060) is classified as Class2)
# Point x94 (value: 0.3355) is classified as Class1)
# Point x95 (value: 0.0288) is classified as Class1)
# Point x96 (value: 0.0194) is classified as Class1)
# Point x97 (value: 0.0044) is classified as Class1)
# Point x98 (value: 0.3732) is classified as Class1)
# Point x99 (value: 0.7116) is classified as Class2)
# Point x100 (value: 0.3834) is classified as Class1)
#
# Results for k = 30:
# Point x51 (value: 0.3944) is classified as Class1)
# Point x52 (value: 0.4510) is classified as Class1)
# Point x53 (value: 0.9226) is classified as Class2)
# Point x54 (value: 0.8060) is classified as Class2)
# Point x55 (value: 0.4008) is classified as Class1)
# Point x56 (value: 0.4099) is classified as Class1)
# Point x57 (value: 0.0149) is classified as Class1)
# Point x58 (value: 0.3972) is classified as Class1)
# Point x59 (value: 0.5175) is classified as Class1)
# Point x60 (value: 0.0292) is classified as Class1)
# Point x61 (value: 0.0844) is classified as Class1)
# Point x62 (value: 0.1957) is classified as Class1)
# Point x63 (value: 0.0299) is classified as Class1)
# Point x64 (value: 0.9175) is classified as Class2)
# Point x65 (value: 0.2251) is classified as Class1)
# Point x66 (value: 0.9181) is classified as Class2)
# Point x67 (value: 0.3570) is classified as Class1)
# Point x68 (value: 0.2049) is classified as Class1)
# Point x69 (value: 0.9364) is classified as Class2)
# Point x70 (value: 0.9456) is classified as Class2)
# Point x71 (value: 0.2084) is classified as Class1)
# Point x72 (value: 0.5485) is classified as Class2)
# Point x73 (value: 0.9976) is classified as Class2)
# Point x74 (value: 0.7723) is classified as Class2)
# Point x75 (value: 0.9661) is classified as Class2)
# Point x76 (value: 0.4098) is classified as Class1)
# Point x77 (value: 0.4916) is classified as Class1)
# Point x78 (value: 0.0469) is classified as Class1)
# Point x79 (value: 0.8428) is classified as Class2)
# Point x80 (value: 0.5137) is classified as Class1)
# Point x81 (value: 0.8904) is classified as Class2)
# Point x82 (value: 0.0329) is classified as Class1)
# Point x83 (value: 0.0187) is classified as Class1)
# Point x84 (value: 0.8048) is classified as Class2)
# Point x85 (value: 0.7959) is classified as Class2)
# Point x86 (value: 0.8088) is classified as Class2)
# Point x87 (value: 0.1517) is classified as Class1)
# Point x88 (value: 0.5373) is classified as Class2)
# Point x89 (value: 0.5950) is classified as Class2)
# Point x90 (value: 0.9586) is classified as Class2)
# Point x91 (value: 0.5196) is classified as Class1)
# Point x92 (value: 0.7182) is classified as Class2)
# Point x93 (value: 0.6060) is classified as Class2)
# Point x94 (value: 0.3355) is classified as Class1)
# Point x95 (value: 0.0288) is classified as Class1)
# Point x96 (value: 0.0194) is classified as Class1)
# Point x97 (value: 0.0044) is classified as Class1)
# Point x98 (value: 0.3732) is classified as Class1)
# Point x99 (value: 0.7116) is classified as Class2)
# Point x100 (value: 0.3834) is classified as Class1)
#
# Classification complete.

# %%
for k, classified_labels in results.items():
 class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"]
 class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"]
 plt.figure(figsize=(10, 6))
 plt.scatter(train_data, [0] * len(train_data), c=["blue" if label == "Class1" else "red" for label in
train_labels], label="Training Data", marker="o")
 plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker="x")
 plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker="x")
 plt.title(f"k-NN Classification Results for k = {k}")
 plt.xlabel("Data Points")
 plt.ylabel("Classification Level")
 plt.legend()
 plt.grid(True)
 plt.show()
